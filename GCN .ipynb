# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
from pathlib import Path
ROOT = Path('.')
gdrive = ROOT/'gdrive'/'My Drive'/'CS247_Project'

list(gdrive.iterdir())
# Out:
# [PosixPath('gdrive/My Drive/CS247_Project/src'),
#  PosixPath('gdrive/My Drive/CS247_Project/.git'),
#  PosixPath('gdrive/My Drive/CS247_Project/data'),
#  PosixPath('gdrive/My Drive/CS247_Project/.DS_Store'),
#  PosixPath('gdrive/My Drive/CS247_Project/.gitignore'),
#  PosixPath('gdrive/My Drive/CS247_Project/data_explore.ipynb'),
#  PosixPath('gdrive/My Drive/CS247_Project/GCN.ipynb')]

# %%
import math
import time
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.nn.parameter import Parameter
from torch.nn.modules.module import Module
import torch.optim as optim

import numpy as np
import pandas as pd
import argparse
import scipy.sparse as sp
import pickle
import easydict
from sklearn.metrics import log_loss, accuracy_score, confusion_matrix
from sklearn.utils.multiclass import unique_labels
from matplotlib import pyplot as plt

# %%
class GraphConvolution(Module):
    """
    Simple rGCN layer, similar to https://arxiv.org/abs/1703.06103
    :param num_relation: number of different relations in the data
    :param num_neighbors: a #relation x #node x 1 matrix that denotes number of neighbors of a node in a relation
    :param in_features: number of feature of the input
    :param out_features: number of feature of the ouput
    :param bias: if bias is added, default is True
    :type num_relation: int
    :type num_relation: int
    :type num_neighbors: array-like object, must be 3 dimension
    :type in_features: int
    :type out_features: int
    :type bias: bool
    """

    def __init__(self, num_relation, num_neighbors, in_features, out_features, bias=True):
        super(GraphConvolution, self).__init__()
        self.in_features = in_features
        self.out_features = out_features
        self.adj_weight = Parameter(nn.init.kaiming_uniform_(torch.FloatTensor(num_relation + 1, in_features, out_features)))
        self.num_neighbors = num_neighbors
        self.feature_weight = Parameter(nn.init.kaiming_uniform_(torch.FloatTensor(in_features, out_features)))
        self.attention = Parameter(nn.init.uniform_(torch.FloatTensor(num_relation + 1)))
        if bias:
            self.bias = Parameter(torch.FloatTensor(out_features))
        else:
            self.register_parameter('bias', None)
        self.reset_parameters()

    def reset_parameters(self):
        stdv = 1. / math.sqrt(self.adj_weight.size(2))
        # self.weight.data.uniform_(-stdv, stdv)
        # self.adj_weight.data.uniform_(-stdv, stdv)
        if self.bias is not None:
            self.bias.data.uniform_(-stdv, stdv)

    def forward(self, input, adjs):
        outputs = []
        num_node = adjs[0].shape[0]
        for i in range(len(self.adj_weight)):
            support = torch.mm(input, self.adj_weight[i])
            output = torch.spmm(adjs[i], support)
#             output = output / self.num_neighbors[i]
            output = output * F.softmax(self.attention, dim=0)[i]
            outputs.append(output)
        output = sum(outputs)
#         output = self.normalization(outputs)
        # feature_out = torch.mm(input, self.feature_weight)
        if self.bias is not None:
            return output + self.bias
        else:
            return output

    def normalization(self, embedding: list) -> torch.Tensor:
        relations = []
        total_sum = 0.0
        for emb in embedding:
            relations.append(torch.sum(emb, dim=0))
        total_sum = sum(relations)
        relations = [relation / total_sum for relation in relations]

        # print(f"relation size {len(relations)}")

        relation_normalization = 0
        outputs = 0
        if embedding[0].device == 'cuda':
            relation_normalization = torch.stack(relations, dim=0).cuda()
            outputs = torch.stack(embedding, dim=0).cuda()
        else:
            relation_normalization = torch.stack(relations, dim=0)
            outputs = torch.stack(embedding, dim=0)
        assert type(relation_normalization) == torch.Tensor
        assert type(outputs) == torch.Tensor

        attention = []
        for i in range(embedding[0].size(1)):
            attention.append(self.attention)
        attention = torch.stack(attention, dim=1)
        attention = F.softmax(attention * relation_normalization, dim=0).reshape(len(embedding), 1, embedding[0].size(1))
        outputs = attention * outputs
        return torch.sum(outputs, dim=0)

    def __repr__(self):
        return self.__class__.__name__ + ' (' + str(self.in_features) + ' -> ' + str(self.out_features) + ')'

# %%
class rGCN(nn.Module):
    def __init__(self, num_relation, num_neighbors, nfeat, nhid, nclass, dropout):
        super(rGCN, self).__init__()

        self.gc1 = GraphConvolution(num_relation, num_neighbors, nfeat, nhid)
        self.gc2 = GraphConvolution(num_relation, num_neighbors, nhid, nclass)
        self.dropout = dropout

        
    '''
    featureless forward function. First x input is a (n x n) all one matrix.
    '''
    def forward(self, x, adjs):
        x = F.relu(self.gc1(x, adjs))
        x = F.dropout(x, self.dropout, training=self.training)
        x = self.gc2(x, adjs)
        return F.log_softmax(x, dim=1)

# %%
def accuracy(output, labels):
    preds = output.max(1)[1].type_as(labels)
    correct = preds.eq(labels).double()
    correct = correct.sum()
    return correct / len(labels)

def sparse_mx_to_torch_sparse_tensor(sparse_mx):
    """Convert a scipy sparse matrix to a torch sparse tensor."""
    sparse_mx = sparse_mx.tocoo().astype(np.float32)
    indices = torch.from_numpy(
        np.vstack((sparse_mx.row, sparse_mx.col)).astype(np.int64))
    values = torch.from_numpy(sparse_mx.data)
    shape = torch.Size(sparse_mx.shape)
    return torch.sparse.FloatTensor(indices, values, shape)

def plot_confusion_matrix(y_true, output, classes,
                          normalize=False,
                          title=None,
                          cmap=plt.cm.Blues, filename = None):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    y_pred = output.max(1)[1].type_as(y_true)
    if not title:
        if normalize:
            title = 'Normalized confusion matrix'
        else:
            title = 'Confusion matrix, without normalization'

    # Compute confusion matrix
    cm = confusion_matrix(y_true, y_pred)
    # Only use the labels that appear in the data
    classes = classes[unique_labels(y_true, y_pred)]
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    #print(cm)

    fig, ax = plt.subplots()
    im = ax.imshow(cm, interpolation='nearest', cmap=cmap)
    ax.figure.colorbar(im, ax=ax)
    # We want to show all ticks...
    ax.set(xticks=np.arange(cm.shape[1]),
           yticks=np.arange(cm.shape[0]),
           # ... and label them with the respective list entries
           xticklabels=classes, yticklabels=classes,
           title=title,
           ylabel='True label',
           xlabel='Predicted label')

    # Rotate the tick labels and set their alignment.
    plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
             rotation_mode="anchor")

    # Loop over data dimensions and create text annotations.
    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            ax.text(j, i, format(cm[i, j], fmt),
                    ha="center", va="center",
                    color="white" if cm[i, j] > thresh else "black", fontsize=6.5)
    fig.tight_layout()
    if filename:
        np.save(filename + '.npy', cm)
        fig.savefig(filename + '.png')
    return ax

def top_k_accuracy(output, labels, k):
    pred = torch.topk(output, k, dim=1)[1].type_as(labels)
    correct = pred.eq(labels.view(-1, 1).expand_as(pred)).double()
    correct = correct.sum()
    return correct / len(labels)

# %%
def train(data, model, optimizer, epoch):
#     features, adjs, idx_train, idx_val, labels = data
    features, adjs, idx_train, labels = data
    for i in range(epoch):
        t = time.time()
        model.train()
        optimizer.zero_grad()
        output = model(features, adjs)
        loss_train = F.nll_loss(output[idx_train], labels[idx_train])
        acc_train = accuracy(output[idx_train], labels[idx_train])
        loss_train.backward()
        optimizer.step()
  
        print('Epoch: {:04d}'.format(i+1),
              'loss_train: {:.4f}'.format(loss_train.item()),
              'acc_train: {:.4f}'.format(acc_train.item()),
              'time: {:.4f}s'.format(time.time() - t))   
#         if not args.fastmode:
#         if True:
#             # Evaluate validation set performance separately,
            # deactivates dropout during validation run.
#             model.eval()
#             output = model(features, adjs)

#         loss_val = F.nll_loss(output[idx_val], labels[idx_val])
#         acc_val = accuracy(output[idx_val], labels[idx_val])
#         print('Epoch: {:04d}'.format(i+1),
#               'loss_train: {:.4f}'.format(loss_train.item()),
#               'acc_train: {:.4f}'.format(acc_train.item()),
#               'loss_val: {:.4f}'.format(loss_val.item()),
#               'acc_val: {:.4f}'.format(acc_val.item()),
#               'time: {:.4f}s'.format(time.time() - t))

# %%
def test(data, model):
    features, adj, idx_test, labels = data
    model.eval()
    output = model(features, adj)
    loss_test = F.nll_loss(output[idx_test], labels[idx_test])
    acc_test = accuracy(output[idx_test], labels[idx_test])
    acc_k_test = top_k_accuracy(output[idx_test], labels[idx_test], 3)
    print("Test set results:",
          "loss= {:.4f}".format(loss_test.item()),
          "accuracy= {:.4f}".format(acc_test.item()),
          "accuracy@3= {:.4f}".format(acc_k_test.item()))
    
    classes = unique_labels(labels)
    plot_confusion_matrix(labels[idx_test], output[idx_test], 
                          classes, normalize=True)

# %%
def multi_relation_load(path="../data/", label="labels.csv", 
                        files=["adj_phone.npz", "adj_app_installed.npz", "adj_app_active.npz"],
                        train='train_idx', test='test_idx'):
    print("Loading data from path {0}".format(path))
    DATA = Path(path)
    ADJS = [DATA/i for i in files]
    LABEL = DATA/label
    adjs = []
    label_df = pd.read_csv(LABEL)
    for adj in ADJS:
        adj_tilde = calculate_laplacian(sp.load_npz(adj))
        adjs.append(adj_tilde)
    
    with open(DATA/train, 'rb') as f:
        idx_train = pickle.load(f)
    with open(DATA/test, 'rb') as f:
        idx_test = pickle.load(f)
    f.close()
    
    labels = label_df['group'].values

    total_node = adjs[0].shape[0]
    edge_indexs = np.array(range(total_node))
#     user_node = len(labels)
#     user_edge_indexs = np.array(range(user_node))
#     self_loop = sp.csr_matrix((np.ones(user_node), (user_edge_indexs, user_edge_indexs)), 
#                               shape=(total_node, total_node), dtype=np.float32)
    self_loop = sp.csr_matrix((np.ones(total_node), (edge_indexs, edge_indexs)), 
                              shape=(total_node, total_node), dtype=np.float32)
    adjs.append(self_loop)

    num_neighbors = [adjs[i].sum(1).reshape(total_node, 1) for i in range(len(adjs))]    
    # num_neighbors = [np.diff(adjs[i].indptr).reshape(n_entities, 1) for i in range(len(adjs))]
    for neighbor in num_neighbors:
        neighbor += 1 # smoothing
    num_neighbors = [torch.Tensor(neighbors) for neighbors in num_neighbors]

    print("\tprocessing features")
    
    # edge_indexs = np.array(range(n_entities))
    features = sp.csr_matrix((np.ones(total_node), (edge_indexs, edge_indexs)), shape=(total_node, total_node), dtype=np.float32) # dummy feature
    
    print("\ttransfering into tensors")

    features = sparse_mx_to_torch_sparse_tensor(features)
    labels = torch.LongTensor(labels)
    adjs = [sparse_mx_to_torch_sparse_tensor(adj) for adj in adjs]

    idx_train = torch.LongTensor(idx_train)
    idx_test = torch.LongTensor(idx_test)

    num_relation = len(files)
    return adjs, features, labels, idx_train, idx_test, num_neighbors, num_relation

# %%
def calculate_laplacian(adj):
    total_nodes = adj.shape[0]
    adj = adj + sp.identity(total_nodes)
    degree = adj.sum(axis=1)
    degree_sqrt_inv = np.sqrt(1.0 / degree).reshape(1, -1)
    D_sqrt_inv = sp.diags(degree_sqrt_inv, [0], shape=(total_nodes, total_nodes))
    adj_tilde = np.dot(np.dot(D_sqrt_inv, adj), D_sqrt_inv)
    return adj_tilde

# %%
def main():
#     parser = argparse.ArgumentParser()
#     parser.add_argument('--epochs', type=int, default=200,
#                         help='Number of epochs to train.')
#     parser.add_argument('--lr', type=float, default=0.01,
#                         help='Initial learning rate.')
#     parser.add_argument('--weight_decay', type=float, default=5e-4,
#                         help='Weight decay (L2 loss on parameters).')
#     parser.add_argument('--hidden', type=int, default=16,
#                         help='Number of hidden units.')
#     parser.add_argument('--dropout', type=float, default=0.5,
#                         help='Dropout rate (1 - keep probability).')
#     parser.add_argument('--data', type=str, default='../../data/twitter_1hop',
#                         help='path of the data folder.')
#     parser.add_argument('--relations', type=str, default=['friend_list.csv'], action='append',
#                         help='edge list files for different relations')

#     args = parser.parse_args()

    args = easydict.EasyDict({
        "epochs": 200,
        "lr": 0.01,
        "weight_decay": 5e-4,
        "hidden": 16,
        "dropout": 0.5,
        "data": 'gdrive/My Drive/CS247_Project/data'
    })

    CUDA = torch.cuda.is_available()
    np.random.seed(42)
    torch.manual_seed(42)
    if CUDA:
        torch.cuda.manual_seed(42)

    DATA = Path(args.data)
#     adjs, features, labels, idx_train, idx_val, idx_test, num_neighbors = multi_relation_load(DATA, files=args.relations)
    adjs, features, labels, idx_train, idx_test, num_neighbors, num_relation = multi_relation_load(DATA)
    if CUDA:
        features = features.cuda(0)
        adjs = [i.cuda(0) for i in adjs]
        labels = labels.cuda(0)
        idx_train = idx_train.cuda(0)
#         idx_val = idx_val.cuda(0)
        idx_test = idx_test.cuda(0)
        num_neighbors = [neighbors.cuda(0) for neighbors in num_neighbors]

    rGCN_model = rGCN(num_relation,
                num_neighbors,
                features.shape[1],
                args.hidden,
                labels.max().item() + 1,
                args.dropout)
    optimizer = optim.Adam(rGCN_model.parameters(),
                           lr=args.lr, weight_decay=args.weight_decay)


    if CUDA:
        # rGCN_model = nn.DataParallel(rGCN_model)
        rGCN_model.cuda(0)

    # t_total = time.time()
    print("start training")
#     train([features, adjs, idx_train, idx_val, labels], rGCN_model, optimizer, args.epochs)
    train([features, adjs, idx_train, labels], rGCN_model, optimizer, args.epochs)
    # print("Optimization Finished!")
    # print("Total time elapsed: {:.4f}s".format(time.time() - t_total))
    test([features, adjs, idx_test, labels], rGCN_model)

# %%
main()
# Out:
# Loading data from path gdrive/My Drive/CS247_Project/data
# 	processing features
# 	transfering into tensors
# start training
# Epoch: 0001 loss_train: 2.5244 acc_train: 0.1171 time: 1.0344s
# Epoch: 0002 loss_train: 2.4762 acc_train: 0.1155 time: 1.0359s
# Epoch: 0003 loss_train: 2.4408 acc_train: 0.1390 time: 1.0548s
# Epoch: 0004 loss_train: 2.4174 acc_train: 0.1435 time: 1.0372s
# Epoch: 0005 loss_train: 2.4029 acc_train: 0.1438 time: 1.0454s
# Epoch: 0006 loss_train: 2.3994 acc_train: 0.1439 time: 1.0313s
# Epoch: 0007 loss_train: 2.3921 acc_train: 0.1492 time: 1.0555s
# Epoch: 0008 loss_train: 2.3864 acc_train: 0.1478 time: 1.0765s
# Epoch: 0009 loss_train: 2.3823 acc_train: 0.1530 time: 1.1116s
# Epoch: 0010 loss_train: 2.3783 acc_train: 0.1502 time: 1.0957s
# Epoch: 0011 loss_train: 2.3745 acc_train: 0.1527 time: 1.0648s
# Epoch: 0012 loss_train: 2.3706 acc_train: 0.1519 time: 1.0587s
# Epoch: 0013 loss_train: 2.3643 acc_train: 0.1570 time: 1.0553s
# Epoch: 0014 loss_train: 2.3621 acc_train: 0.1603 time: 1.0538s
# Epoch: 0015 loss_train: 2.3550 acc_train: 0.1724 time: 1.0532s
# Epoch: 0016 loss_train: 2.3536 acc_train: 0.1621 time: 1.0745s
# Epoch: 0017 loss_train: 2.3458 acc_train: 0.1688 time: 1.1476s
# Epoch: 0018 loss_train: 2.3385 acc_train: 0.1646 time: 1.1702s
# Epoch: 0019 loss_train: 2.3350 acc_train: 0.1701 time: 1.0755s
# Epoch: 0020 loss_train: 2.3265 acc_train: 0.1809 time: 1.0534s
# Epoch: 0021 loss_train: 2.3190 acc_train: 0.1783 time: 1.0467s
# Epoch: 0022 loss_train: 2.3112 acc_train: 0.1854 time: 1.0603s
# Epoch: 0023 loss_train: 2.3029 acc_train: 0.1967 time: 1.0686s
# Epoch: 0024 loss_train: 2.2920 acc_train: 0.1939 time: 1.0778s
# Epoch: 0025 loss_train: 2.2853 acc_train: 0.2011 time: 1.0917s
# Epoch: 0026 loss_train: 2.2729 acc_train: 0.2001 time: 1.0993s
# Epoch: 0027 loss_train: 2.2627 acc_train: 0.2027 time: 1.0961s
# Epoch: 0028 loss_train: 2.2537 acc_train: 0.2006 time: 1.0451s
# Epoch: 0029 loss_train: 2.2461 acc_train: 0.2073 time: 1.0415s
# Epoch: 0030 loss_train: 2.2360 acc_train: 0.2075 time: 1.0347s
# Epoch: 0031 loss_train: 2.2237 acc_train: 0.2189 time: 1.0432s
# Epoch: 0032 loss_train: 2.2125 acc_train: 0.2251 time: 1.0511s
# Epoch: 0033 loss_train: 2.2053 acc_train: 0.2225 time: 1.0301s
# Epoch: 0034 loss_train: 2.1979 acc_train: 0.2319 time: 1.0367s
# Epoch: 0035 loss_train: 2.1938 acc_train: 0.2219 time: 1.0883s
# Epoch: 0036 loss_train: 2.1814 acc_train: 0.2337 time: 1.0594s
# Epoch: 0037 loss_train: 2.1776 acc_train: 0.2404 time: 1.1086s
# Epoch: 0038 loss_train: 2.1694 acc_train: 0.2363 time: 1.0943s
# Epoch: 0039 loss_train: 2.1656 acc_train: 0.2494 time: 1.0619s
# Epoch: 0040 loss_train: 2.1527 acc_train: 0.2447 time: 1.0620s
# Epoch: 0041 loss_train: 2.1429 acc_train: 0.2484 time: 1.0622s
# Epoch: 0042 loss_train: 2.1414 acc_train: 0.2480 time: 1.0693s
# Epoch: 0043 loss_train: 2.1322 acc_train: 0.2499 time: 1.0655s
# Epoch: 0044 loss_train: 2.1309 acc_train: 0.2572 time: 1.0398s
# Epoch: 0045 loss_train: 2.1330 acc_train: 0.2692 time: 1.0588s
# Epoch: 0046 loss_train: 2.1181 acc_train: 0.2655 time: 1.0576s
# Epoch: 0047 loss_train: 2.1268 acc_train: 0.2597 time: 1.0776s
# Epoch: 0048 loss_train: 2.1243 acc_train: 0.2545 time: 1.0515s
# Epoch: 0049 loss_train: 2.1167 acc_train: 0.2533 time: 1.0507s
# Epoch: 0050 loss_train: 2.1012 acc_train: 0.2643 time: 1.0291s
# Epoch: 0051 loss_train: 2.1136 acc_train: 0.2679 time: 1.0490s
# Epoch: 0052 loss_train: 2.1041 acc_train: 0.2755 time: 1.0592s
# Epoch: 0053 loss_train: 2.1040 acc_train: 0.2685 time: 1.0463s
# Epoch: 0054 loss_train: 2.1061 acc_train: 0.2591 time: 1.0408s
# Epoch: 0055 loss_train: 2.1141 acc_train: 0.2621 time: 1.0430s
# Epoch: 0056 loss_train: 2.0795 acc_train: 0.2747 time: 1.0787s
# Epoch: 0057 loss_train: 2.0872 acc_train: 0.2753 time: 1.0657s
# Epoch: 0058 loss_train: 2.0815 acc_train: 0.2797 time: 1.0637s
# Epoch: 0059 loss_train: 2.0755 acc_train: 0.2774 time: 1.0779s
# Epoch: 0060 loss_train: 2.0830 acc_train: 0.2824 time: 1.0583s
# Epoch: 0061 loss_train: 2.0609 acc_train: 0.2966 time: 1.0793s
# Epoch: 0062 loss_train: 2.0695 acc_train: 0.2820 time: 1.0637s
# Epoch: 0063 loss_train: 2.0683 acc_train: 0.2866 time: 1.0420s
# Epoch: 0064 loss_train: 2.0592 acc_train: 0.2849 time: 1.0400s
# Epoch: 0065 loss_train: 2.0621 acc_train: 0.2810 time: 1.0404s
# Epoch: 0066 loss_train: 2.0695 acc_train: 0.2783 time: 1.0543s
# Epoch: 0067 loss_train: 2.0455 acc_train: 0.2929 time: 1.0384s
# Epoch: 0068 loss_train: 2.0599 acc_train: 0.2916 time: 1.0203s
# Epoch: 0069 loss_train: 2.0503 acc_train: 0.2999 time: 1.0240s
# Epoch: 0070 loss_train: 2.0480 acc_train: 0.2932 time: 1.0374s
# Epoch: 0071 loss_train: 2.0460 acc_train: 0.2866 time: 1.0503s
# Epoch: 0072 loss_train: 2.0505 acc_train: 0.2824 time: 1.0530s
# Epoch: 0073 loss_train: 2.0414 acc_train: 0.2874 time: 1.0251s
# Epoch: 0074 loss_train: 2.0353 acc_train: 0.2933 time: 1.0937s
# Epoch: 0075 loss_train: 2.0290 acc_train: 0.3013 time: 1.0905s
# Epoch: 0076 loss_train: 2.0333 acc_train: 0.3021 time: 1.1071s
# Epoch: 0077 loss_train: 2.0326 acc_train: 0.3053 time: 1.1045s
# Epoch: 0078 loss_train: 2.0290 acc_train: 0.3056 time: 1.0939s
# Epoch: 0079 loss_train: 2.0210 acc_train: 0.3032 time: 1.1072s
# Epoch: 0080 loss_train: 2.0187 acc_train: 0.2991 time: 1.1053s
# Epoch: 0081 loss_train: 2.0182 acc_train: 0.2966 time: 1.0877s
# Epoch: 0082 loss_train: 2.0262 acc_train: 0.2909 time: 1.0707s
# Epoch: 0083 loss_train: 2.0156 acc_train: 0.2975 time: 1.0947s
# Epoch: 0084 loss_train: 2.0216 acc_train: 0.3049 time: 1.0701s
# Epoch: 0085 loss_train: 2.0128 acc_train: 0.3123 time: 1.0590s
# Epoch: 0086 loss_train: 2.0251 acc_train: 0.3074 time: 1.0328s
# Epoch: 0087 loss_train: 2.0002 acc_train: 0.3076 time: 1.0324s
# Epoch: 0088 loss_train: 2.0044 acc_train: 0.3079 time: 1.0405s
# Epoch: 0089 loss_train: 2.0116 acc_train: 0.3025 time: 1.0225s
# Epoch: 0090 loss_train: 2.0098 acc_train: 0.2974 time: 1.0282s
# Epoch: 0091 loss_train: 1.9999 acc_train: 0.3068 time: 1.0352s
# Epoch: 0092 loss_train: 1.9914 acc_train: 0.3155 time: 1.0297s
# Epoch: 0093 loss_train: 1.9963 acc_train: 0.3151 time: 1.0306s
# Epoch: 0094 loss_train: 1.9932 acc_train: 0.3168 time: 1.0202s
# Epoch: 0095 loss_train: 1.9944 acc_train: 0.3179 time: 1.0606s
# Epoch: 0096 loss_train: 1.9840 acc_train: 0.3167 time: 1.0448s
# Epoch: 0097 loss_train: 1.9797 acc_train: 0.3147 time: 1.0278s
# Epoch: 0098 loss_train: 1.9903 acc_train: 0.3061 time: 1.0292s
# Epoch: 0099 loss_train: 1.9919 acc_train: 0.3035 time: 1.0367s
# Epoch: 0100 loss_train: 1.9753 acc_train: 0.3178 time: 1.0428s
# Epoch: 0101 loss_train: 1.9776 acc_train: 0.3161 time: 1.0443s
# Epoch: 0102 loss_train: 1.9796 acc_train: 0.3193 time: 1.0498s
# Epoch: 0103 loss_train: 1.9720 acc_train: 0.3179 time: 1.0461s
# Epoch: 0104 loss_train: 1.9758 acc_train: 0.3167 time: 1.0372s
# Epoch: 0105 loss_train: 1.9625 acc_train: 0.3218 time: 1.0446s
# Epoch: 0106 loss_train: 1.9637 acc_train: 0.3176 time: 1.0410s
# Epoch: 0107 loss_train: 1.9597 acc_train: 0.3196 time: 1.0435s
# Epoch: 0108 loss_train: 1.9542 acc_train: 0.3262 time: 1.0415s
# Epoch: 0109 loss_train: 1.9534 acc_train: 0.3305 time: 1.0402s
# Epoch: 0110 loss_train: 1.9554 acc_train: 0.3336 time: 1.0228s
# Epoch: 0111 loss_train: 1.9496 acc_train: 0.3241 time: 1.0456s
# Epoch: 0112 loss_train: 1.9543 acc_train: 0.3244 time: 1.0341s
# Epoch: 0113 loss_train: 1.9442 acc_train: 0.3215 time: 1.0312s
# Epoch: 0114 loss_train: 1.9453 acc_train: 0.3239 time: 1.0181s
# Epoch: 0115 loss_train: 1.9377 acc_train: 0.3293 time: 1.0517s
# Epoch: 0116 loss_train: 1.9335 acc_train: 0.3357 time: 1.0851s
# Epoch: 0117 loss_train: 1.9295 acc_train: 0.3338 time: 1.0901s
# Epoch: 0118 loss_train: 1.9305 acc_train: 0.3350 time: 1.1054s
# Epoch: 0119 loss_train: 1.9248 acc_train: 0.3340 time: 1.0801s
# Epoch: 0120 loss_train: 1.9303 acc_train: 0.3306 time: 1.0878s
# Epoch: 0121 loss_train: 1.9188 acc_train: 0.3366 time: 1.0683s
# Epoch: 0122 loss_train: 1.9177 acc_train: 0.3342 time: 1.0621s
# Epoch: 0123 loss_train: 1.9169 acc_train: 0.3362 time: 1.0688s
# Epoch: 0124 loss_train: 1.9105 acc_train: 0.3347 time: 1.0959s
# Epoch: 0125 loss_train: 1.9119 acc_train: 0.3398 time: 1.0626s
# Epoch: 0126 loss_train: 1.9107 acc_train: 0.3379 time: 1.0297s
# Epoch: 0127 loss_train: 1.9068 acc_train: 0.3469 time: 1.0322s
# Epoch: 0128 loss_train: 1.8980 acc_train: 0.3422 time: 1.0523s
# Epoch: 0129 loss_train: 1.8989 acc_train: 0.3432 time: 1.0883s
# Epoch: 0130 loss_train: 1.8972 acc_train: 0.3433 time: 1.0829s
# Epoch: 0131 loss_train: 1.9005 acc_train: 0.3423 time: 1.0826s
# Epoch: 0132 loss_train: 1.8969 acc_train: 0.3503 time: 1.0502s
# Epoch: 0133 loss_train: 1.8871 acc_train: 0.3516 time: 1.0573s
# Epoch: 0134 loss_train: 1.8912 acc_train: 0.3467 time: 1.0840s
# Epoch: 0135 loss_train: 1.8888 acc_train: 0.3467 time: 1.0837s
# Epoch: 0136 loss_train: 1.8872 acc_train: 0.3482 time: 1.1094s
# Epoch: 0137 loss_train: 1.8818 acc_train: 0.3498 time: 1.1039s
# Epoch: 0138 loss_train: 1.8847 acc_train: 0.3449 time: 1.1130s
# Epoch: 0139 loss_train: 1.8761 acc_train: 0.3506 time: 1.1120s
# Epoch: 0140 loss_train: 1.8758 acc_train: 0.3527 time: 1.0862s
# Epoch: 0141 loss_train: 1.8749 acc_train: 0.3505 time: 1.1014s
# Epoch: 0142 loss_train: 1.8750 acc_train: 0.3519 time: 1.0745s
# Epoch: 0143 loss_train: 1.8677 acc_train: 0.3538 time: 1.0459s
# Epoch: 0144 loss_train: 1.8687 acc_train: 0.3494 time: 1.0376s
# Epoch: 0145 loss_train: 1.8635 acc_train: 0.3539 time: 1.0423s
# Epoch: 0146 loss_train: 1.8647 acc_train: 0.3554 time: 1.0554s
# Epoch: 0147 loss_train: 1.8686 acc_train: 0.3550 time: 1.0715s
# Epoch: 0148 loss_train: 1.8574 acc_train: 0.3571 time: 1.0661s
# Epoch: 0149 loss_train: 1.8615 acc_train: 0.3588 time: 1.0440s
# Epoch: 0150 loss_train: 1.8539 acc_train: 0.3584 time: 1.0338s
# Epoch: 0151 loss_train: 1.8540 acc_train: 0.3594 time: 1.0359s
# Epoch: 0152 loss_train: 1.8520 acc_train: 0.3613 time: 1.0512s
# Epoch: 0153 loss_train: 1.8492 acc_train: 0.3625 time: 1.0630s
# Epoch: 0154 loss_train: 1.8439 acc_train: 0.3637 time: 1.0396s
# Epoch: 0155 loss_train: 1.8468 acc_train: 0.3593 time: 1.0538s
# Epoch: 0156 loss_train: 1.8410 acc_train: 0.3589 time: 1.0405s
# Epoch: 0157 loss_train: 1.8362 acc_train: 0.3615 time: 1.0597s
# Epoch: 0158 loss_train: 1.8356 acc_train: 0.3683 time: 1.0679s
# Epoch: 0159 loss_train: 1.8287 acc_train: 0.3754 time: 1.0748s
# Epoch: 0160 loss_train: 1.8328 acc_train: 0.3708 time: 1.0705s
# Epoch: 0161 loss_train: 1.8341 acc_train: 0.3661 time: 1.0469s
# Epoch: 0162 loss_train: 1.8296 acc_train: 0.3628 time: 1.0450s
# Epoch: 0163 loss_train: 1.8205 acc_train: 0.3661 time: 1.0278s
# Epoch: 0164 loss_train: 1.8258 acc_train: 0.3635 time: 1.0377s
# Epoch: 0165 loss_train: 1.8197 acc_train: 0.3702 time: 1.0305s
# Epoch: 0166 loss_train: 1.8248 acc_train: 0.3701 time: 1.0450s
# Epoch: 0167 loss_train: 1.8123 acc_train: 0.3756 time: 1.0363s
# Epoch: 0168 loss_train: 1.8155 acc_train: 0.3694 time: 1.0609s
# Epoch: 0169 loss_train: 1.8186 acc_train: 0.3678 time: 1.0364s
# Epoch: 0170 loss_train: 1.8153 acc_train: 0.3717 time: 1.0632s
# Epoch: 0171 loss_train: 1.8192 acc_train: 0.3694 time: 1.0462s
# Epoch: 0172 loss_train: 1.8099 acc_train: 0.3729 time: 1.0600s
# Epoch: 0173 loss_train: 1.8099 acc_train: 0.3720 time: 1.0866s
# Epoch: 0174 loss_train: 1.8016 acc_train: 0.3725 time: 1.0724s
# Epoch: 0175 loss_train: 1.8077 acc_train: 0.3760 time: 1.0289s
# Epoch: 0176 loss_train: 1.7999 acc_train: 0.3766 time: 1.0515s
# Epoch: 0177 loss_train: 1.8047 acc_train: 0.3712 time: 1.0398s
# Epoch: 0178 loss_train: 1.8031 acc_train: 0.3743 time: 1.0414s
# Epoch: 0179 loss_train: 1.7941 acc_train: 0.3768 time: 1.0620s
# Epoch: 0180 loss_train: 1.7998 acc_train: 0.3721 time: 1.0401s
# Epoch: 0181 loss_train: 1.7887 acc_train: 0.3805 time: 1.0493s
# Epoch: 0182 loss_train: 1.7864 acc_train: 0.3855 time: 1.0807s
# Epoch: 0183 loss_train: 1.7899 acc_train: 0.3796 time: 1.0871s
# Epoch: 0184 loss_train: 1.7873 acc_train: 0.3793 time: 1.0602s
# Epoch: 0185 loss_train: 1.7896 acc_train: 0.3782 time: 1.0581s
# Epoch: 0186 loss_train: 1.7850 acc_train: 0.3804 time: 1.0301s
# Epoch: 0187 loss_train: 1.7807 acc_train: 0.3790 time: 1.0797s
# Epoch: 0188 loss_train: 1.7841 acc_train: 0.3828 time: 1.0843s
# Epoch: 0189 loss_train: 1.7793 acc_train: 0.3847 time: 1.0597s
# Epoch: 0190 loss_train: 1.7797 acc_train: 0.3785 time: 1.0385s
# Epoch: 0191 loss_train: 1.7758 acc_train: 0.3881 time: 1.0395s
# Epoch: 0192 loss_train: 1.7790 acc_train: 0.3802 time: 1.0532s
# Epoch: 0193 loss_train: 1.7684 acc_train: 0.3864 time: 1.0562s
# Epoch: 0194 loss_train: 1.7752 acc_train: 0.3818 time: 1.0688s
# Epoch: 0195 loss_train: 1.7815 acc_train: 0.3783 time: 1.0966s
# Epoch: 0196 loss_train: 1.7657 acc_train: 0.3913 time: 1.0744s
# Epoch: 0197 loss_train: 1.7701 acc_train: 0.3862 time: 1.1446s
# Epoch: 0198 loss_train: 1.7702 acc_train: 0.3878 time: 1.1219s
# Epoch: 0199 loss_train: 1.7655 acc_train: 0.3836 time: 1.0895s
# Epoch: 0200 loss_train: 1.7734 acc_train: 0.3798 time: 1.0686s
# Test set results: loss= 2.0373 accuracy= 0.2986 accuracy@3= 0.6149
# Normalized confusion matrix
